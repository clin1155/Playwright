# %%
def greetings():
    print("Hi there, how can I help you?")


if __name__ =='__main__':
    greetings()
# Out:
# Hi there, how can I help you?

# %%
import math as m
result=m.gcd(33,100)
print(result)
# Out:
# 1

# %%
from playwright.sync_api import sync_playwright
sync_playwright()

# %%
with open("somthing.txt") as file:
    content=file.read()
print(content)
# Out:
# Cat woman kisses, the Dark Knight rises~
