# %%
age=25
if age>60:
    print("Senior")
elif age>30:
    print("Adult")
else:
    print("junior")
# Out:
# junior

# %%
furry = False
small = True

if furry:
    print("這是有毛的")
    if small:
        print("這是小的")
        print("它是貓")
    else:
        print("這是大的")
        print("它是熊")
else:
    print("這是代表沒有毛")
    if small:
        print("這是小的")
        print("它是小蜥蜴")
    else:
        print("這是大的")
        print("它是人類或是沒毛的熊")
# Out:
# 這是代表沒有毛
# 這是小的
# 它是小蜥蜴

# %%
x = int(input("請輸入 x:"))
y = int(input("請輸入 y:"))

if x >= 0:
    root = x ** (1/y)
else:
    if y % 2 == 0:
        root = "虛數"
    else:
        root = -(-x) ** (1 / y)

print("root=", root)
# Out:
# 請輸入 x: 40
# 請輸入 y: -9
# root= 0.6637328831200571
