# %%
try:
    money = int(input("請輸入金額:"))
    print(f"輸入的金額是{money}") #f"string"
except ValueError as e:
    print(f"輸入錯誤:{e}")
# Out:
# 請輸入金額: 100
# 輸入的金額是100

# %%
import random

rand_list = random.sample(range(1, 101), 100)
print(rand_list)
# Out:
# [24, 15, 94, 33, 55, 96, 29, 18, 1, 99, 6, 25, 61, 71, 56, 26, 65, 39, 76, 32, 88, 46, 70, 54, 34, 57, 52, 11, 64, 91, 23, 92, 51, 3, 31, 73, 35, 12, 7, 85, 48, 22, 50, 19, 8, 49, 38, 42, 66, 5, 47, 68, 78, 79, 60, 72, 14, 83, 63, 53, 16, 45, 93, 17, 100, 37, 84, 58, 10, 90, 67, 62, 43, 20, 59, 2, 21, 89, 69, 81, 95, 28, 97, 27, 86, 30, 82, 98, 77, 13, 4, 75, 74, 80, 9, 87, 44, 40, 36, 41]
